# %% [markdown]
# # 🎵 Next-Gen AI Audio Workstation (Colab Edition)
# **Created by Music Revolutionary JAESOO**
#
# 이 노트북은 구글 코랩(Google Colab) 환경에서 AI 오디오 작업을 수행하기 위해 제작되었습니다.
# GitHub 저장소에서 자동으로 최신 코드를 불러옵니다.
#
# ### ⚠️ 중요: 런타임 유형 변경
# 1. 상단 메뉴에서 **런타임** > **런타임 유형 변경**을 클릭하세요.
# 2. **하드웨어 가속기**를 **GPU** (T4 등)로 선택하고 저장하세요.

# %%
# 1. GPU 확인
# !nvidia-smi

# %%
# 2. 환경 설정 (GitHub Clone)
import os

repo_url = 'https://github.com/jaesooPark1972/MusicSoundLevelUP.git'
repo_dir = 'MusicSoundLevelUP'

if os.path.exists(repo_dir):
    print(f"📂 '{repo_dir}' 폴더가 이미 존재합니다. 업데이트(pull)를 시도합니다...")
    # %cd {repo_dir}
    # !git pull
else:
    print("📂 GitHub 저장소를 복제합니다...")
    # !git clone {repo_url}
    # %cd {repo_dir}

# colab_setup 폴더로 이동 (실행 파일이 여기에 있음)
if os.path.exists('colab_setup'):
    # %cd colab_setup
    print("📂 colab_setup 폴더로 이동했습니다.")

print("✅ 설정 및 경로 이동 완료!")
print(f"Current working directory: {os.getcwd()}")

# %%
# 3. 구글 드라이브 마운트 (결과 저장용 - 선택사항)
from google.colab import drive
import os

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
    print("✅ 구글 드라이브 연결 완료")

# %%
# 4. 필수 프로그램 및 라이브러리 설치
# !apt-get update
# !apt-get install -y ffmpeg
# !pip install -r requirements.txt

# %%
# 5. 앱 실행 (Web UI)
# 실행 후 나타나는 'Running on public URL' 링크를 클릭하세요.
# !python colab_app.py
